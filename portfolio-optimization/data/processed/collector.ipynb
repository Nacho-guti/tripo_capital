# %%
import pandas as pd
import sqlite3
from datetime import datetime
import os

# %%
# First, let's see where Python is looking
print("Current working directory:")
print(os.getcwd())

os.chdir(os.path.expanduser("~"))
os.chdir("Documents/2_PP/WM/portfolio-optimization/data/raw/")

# Let's see what files are in your current folder
print("\nFiles in current directory:")
print(os.listdir("."))
# Out:
# Current working directory:
# /Users/nachogutierrezdelaroza/Documents/2_PP/WM/portfolio-optimization/data/raw
#
# Files in current directory:
# ['.DS_Store', 'risk_free', 'bonds', 'cash', 'benchmarks', 'alternatives', 'equities']

# %%
file_path = "equities/min_vol/euro_min_vol_etf.xlsx"
df = pd.read_excel(file_path)

print("Raw data:")
print(df.head())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())

print("\nSummary statistics:")
# Out:
# Raw data:
#         Date  Last Price                                               Name
# 0 2025-06-04        6.82  iNAV iShares Edge MSCI Europe Minimum Volatili...
# 1 2025-06-03        6.79                                                NaN
# 2 2025-06-02        6.83                                                NaN
# 3 2025-05-30        6.82                                                NaN
# 4 2025-05-29        6.80                                                NaN
#
# Data types:
# Date          datetime64[ns]
# Last Price           float64
# Name                  object
# dtype: object
#
# Missing values:
# Date             0
# Last Price       0
# Name          1294
# dtype: int64
#
# Summary statistics:

# %%
# Finding excel files
def find_all_excel_files(root_folder):
    """
    Find all Excel files in all subfolders
    """
    excel_files = [] # Creates an empty list, at the start, which will be filled with the paths of the excel files found in the subfolders
    
    # Walk through all folders and subfolders
    for root, dirs, files in os.walk(root_folder):
        # Skip if path contains risk_free
        if "risk_free" in root:
            
            continue

        for file in files:
            if file.endswith(('.xlsx', '.xls')):
                full_path = os.path.join(root, file)
                excel_files.append(full_path)
    
    return excel_files

# Find all your Excel files
root_folder = "."  # Adjust this path to your data folder
excel_files = find_all_excel_files(root_folder)

print(f"Found {len(excel_files)} Excel files:")
for file in excel_files:
    print(f"  📄 {file}")
# Out:
# Found 32 Excel files:
#   📄 ./bonds/em_bond_etf.xlsx
#   📄 ./bonds/jp_ult_sht_cor_bond_etf.xlsx
#   📄 ./bonds/ish_wld_cor_bond_etf.xlsx
#   📄 ./bonds/ubs_bbs_tips_bonds_etf.xlsx
#   📄 ./bonds/ish_glob_bond_etf.xlsx
#   📄 ./benchmarks/ftse_balance_prices.xlsx
#   📄 ./alternatives/gold_etf.xlsx
#   📄 ./alternatives/vici_reits_aim_etf.xlsx
#   📄 ./alternatives/aim_data_centr_etf.xlsx
#   📄 ./equities/etf_comparison_results.xlsx
#   📄 ./equities/uk10y_gilt.xlsx
#   📄 ./equities/min_vol/world_min_vol_etf.xlsx
#   📄 ./equities/min_vol/euro_min_vol_etf.xlsx
#   📄 ./equities/min_vol/snp_min_vol_etf.xlsx
#   📄 ./equities/min_vol/em_min_vol_etf.xlsx
#   📄 ./equities/us/ish_na_eq_etf.xlsx
#   📄 ./equities/us/spdr_world_tech.xlsx
#   📄 ./equities/us/amu_rai_us_etf.xlsx
#   📄 ./equities/em/hsbc_china_em_etf.xlsx
#   📄 ./equities/em/artemis_em_etf.xlsx
#   📄 ./equities/em/hsbc_frontier_etf.xlsx
#   📄 ./equities/other/bnp_aqua_etf.xlsx
#   📄 ./equities/other/gam_sus_em_etf.xlsx
#   📄 ./equities/other/acs_esg_etf.xlsx
#   📄 ./equities/other/bgf_sus_etf.xlsx
#   📄 ./equities/other/pic_env_etf.xlsx
#   📄 ./equities/uk_large_cap/uklarge_ishares_etf.xlsx
#   📄 ./equities/uk_large_cap/uklarge_inv_etf.xlsx
#   📄 ./equities/uk_large_cap/uklarge_vanguard_etf.xlsx
#   📄 ./equities/dev_ex_us/fid_gro_exus_etf.xlsx
#   📄 ./equities/dev_ex_us/ish_quality_exus_etf.xlsx
#   📄 ./equities/dev_ex_us/van_esg_exus_etf.xlsx

# %%
def create_master_dataframe(excel_files):
    """
    Create master DataFrame of all securities
    """
    master_df = None
    
    for file_path in excel_files:
        try:
            print(f"Processing: {file_path}")
            
            # Read the Excel file
            df = pd.read_excel(file_path)
            
            # Get the single security name | dropna() makes the name the only value in the column
            security_name = df['Name'].dropna().iloc[0]

            print(f"Found security: {security_name}")

            # Prepare the dataframe for the master dataframe
            clean_df = df[['Date', 'Last Price']].copy()
            clean_df = clean_df.rename(columns={'Last Price': security_name})
            clean_df = clean_df.dropna()

            # Covert date column to datetime
            clean_df['Date'] = pd.to_datetime(clean_df['Date'], dayfirst=True)

            # First file: create master dataframe
            if master_df is None:
                master_df = clean_df
                print(f"Created master with Date column and: {security_name}")
            else:
                # Subsequent files: drop the Date column and add the new security
                price_series = clean_df.set_index('Date')[security_name]
                price_series.name = security_name

                # Add to master dataframe
                master_df = master_df.set_index('Date')
                master_df[security_name] = price_series
                master_df = master_df.reset_index()

                print(f"Added {security_name} to master")
    
        except Exception as e:
            print(f"Error with {file_path}: {e}")

    # Sort by date and reset index 
    master_df = master_df.sort_values(by='Date').reset_index(drop=True)
    
    return master_df

# Create your master dataframe
master_df = create_master_dataframe(excel_files)

print(f"\n🎉 Master DataFrame created!")
print(f"Shape: {master_df.shape[0]} rows, {master_df.shape[1]} columns")
print(f"Columns: {list(master_df.columns)}")
print("\nFirst few rows:")
print(master_df.head())
# Out:
# Processing: ./bonds/em_bond_etf.xlsx
# Found security: iShares J.P. Morgan USD EM Bond UCITS ETF (GBP hedged)
# Created master with Date column and: iShares J.P. Morgan USD EM Bond UCITS ETF (GBP hedged)
# Processing: ./bonds/jp_ult_sht_cor_bond_etf.xlsx
# Found security: JPMorgan GBP Ultra-Short Income UCITS ETF GBP (Acc)
# Added JPMorgan GBP Ultra-Short Income UCITS ETF GBP (Acc) to master
# Processing: ./bonds/ish_wld_cor_bond_etf.xlsx
# Found security: iShares Global Corp Bond UCITS ETF GBP Hedged
# Added iShares Global Corp Bond UCITS ETF GBP Hedged to master
# Processing: ./bonds/ubs_bbs_tips_bonds_etf.xlsx
# Found security: BBG TIPS 1-10 UCITS ETF
# Added BBG TIPS 1-10 UCITS ETF to master
# Processing: ./bonds/ish_glob_bond_etf.xlsx
# Found security: iShares Core Global Aggregate Bond UCITS ETF
# Added iShares Core Global Aggregate Bond UCITS ETF to master
# Processing: ./benchmarks/ftse_balance_prices.xlsx
# Error with ./benchmarks/ftse_balance_prices.xlsx: 'Name'
# Processing: ./alternatives/gold_etf.xlsx
# Found security: iShares Physical Gold GBP Hedged ETC
# Added iShares Physical Gold GBP Hedged ETC to master
# Processing: ./alternatives/vici_reits_aim_etf.xlsx
# Found security: VICI Properties INC
# Added VICI Properties INC to master
# Processing: ./alternatives/aim_data_centr_etf.xlsx
# Found security: Digital Realty Trust Inc
# Added Digital Realty Trust Inc to master
# Processing: ./equities/etf_comparison_results.xlsx
# Found security: iShares Emerging Markets Minimum Volatility
# Error with ./equities/etf_comparison_results.xlsx: "None of [Index(['Date', 'Last Price'], dtype='object')] are in the [columns]"
# Processing: ./equities/uk10y_gilt.xlsx
# Found security: UK Gilt 10Y
# Added UK Gilt 10Y to master
# Processing: ./equities/min_vol/world_min_vol_etf.xlsx
# Found security: World_min_vol_etf
# Added World_min_vol_etf to master
# Processing: ./equities/min_vol/euro_min_vol_etf.xlsx
# Found security: iNAV iShares Edge MSCI Europe Minimum Volatility Advanced UCITS ETF EUR Acc GBP
# Added iNAV iShares Edge MSCI Europe Minimum Volatility Advanced UCITS ETF EUR Acc GBP to master
# Processing: ./equities/min_vol/snp_min_vol_etf.xlsx
# Found security: snp_min_vol_etf
# Added snp_min_vol_etf to master
# Processing: ./equities/min_vol/em_min_vol_etf.xlsx
# Found security: ISHARES EDGE MSCI EM MIN VOL
# Added ISHARES EDGE MSCI EM MIN VOL to master
# Processing: ./equities/us/ish_na_eq_etf.xlsx
# Found security: iShares North Amrican Equity Index Fund (UK)
# Added iShares North Amrican Equity Index Fund (UK) to master
# Processing: ./equities/us/spdr_world_tech.xlsx
# Found security: SPDR World Technology
# Added SPDR World Technology to master
# Processing: ./equities/us/amu_rai_us_etf.xlsx
# Found security: Amundi MSCI Robotics & AI ESG
# Added Amundi MSCI Robotics & AI ESG to master
# Processing: ./equities/em/hsbc_china_em_etf.xlsx
# Found security: HSBC MSCI China A UCITS ETF GBP iNAV
# Added HSBC MSCI China A UCITS ETF GBP iNAV  to master
# Processing: ./equities/em/artemis_em_etf.xlsx
# Found security: Artemis Global Emerging Markets Fund
# Added Artemis Global Emerging Markets Fund to master
# Processing: ./equities/em/hsbc_frontier_etf.xlsx
# Found security: HSBC Global investment funds - Frontier Markets (USD) - took GBP price
# Added HSBC Global investment funds - Frontier Markets (USD) - took GBP price to master
# Processing: ./equities/other/bnp_aqua_etf.xlsx
# Found security: BNP Paribas Funds - Aqua
# Added BNP Paribas Funds - Aqua to master
# Processing: ./equities/other/gam_sus_em_etf.xlsx
# Found security: GAM Sustainable Emerging Equtiy
# Added GAM Sustainable Emerging Equtiy to master
# Processing: ./equities/other/acs_esg_etf.xlsx
# Found security: ACS World ESG Insight Equity Fund
# Added ACS World ESG Insight Equity Fund to master
# Processing: ./equities/other/bgf_sus_etf.xlsx
# Found security: Black Rock Global Funds - Sustainable Energy Fund (new energy companies, emphasis on renewables and low emissions)
# Added Black Rock Global Funds - Sustainable Energy Fund (new energy companies, emphasis on renewables and low emissions) to master
# Processing: ./equities/other/pic_env_etf.xlsx
# Found security: Pictet - Global environmental opportunities
# Added Pictet - Global environmental opportunities to master
# Processing: ./equities/uk_large_cap/uklarge_ishares_etf.xlsx
# Found security: ISHARES CORE FTSE 100 ACC
# Added ISHARES CORE FTSE 100 ACC to master
# Processing: ./equities/uk_large_cap/uklarge_inv_etf.xlsx
# Found security: INVESCO FTSE RAFI UK 100
# Added INVESCO FTSE RAFI UK 100 to master
# Processing: ./equities/uk_large_cap/uklarge_vanguard_etf.xlsx
# Found security: VANG FTSE100 GBPD
# Added VANG FTSE100 GBPD to master
# Processing: ./equities/dev_ex_us/fid_gro_exus_etf.xlsx
# Found security: Fidelity Funds - European Dynamic Growth Fund
# Added Fidelity Funds - European Dynamic Growth Fund to master
# Processing: ./equities/dev_ex_us/ish_quality_exus_etf.xlsx
# Found security: iShares Edge MSCI Europe Quality Factor UCITS ETF
# Added iShares Edge MSCI Europe Quality Factor UCITS ETF to master
# Processing: ./equities/dev_ex_us/van_esg_exus_etf.xlsx
# Found security: Vanguard ESG Developed Europe Index Fund (EUR)
# Added Vanguard ESG Developed Europe Index Fund (EUR) to master
#
# 🎉 Master DataFrame created!
# Shape: 1276 rows, 31 columns
# Columns: ['Date', 'iShares J.P. Morgan USD EM Bond UCITS ETF (GBP hedged)', 'JPMorgan GBP Ultra-Short Income UCITS ETF GBP (Acc)', 'iShares Global Corp Bond UCITS ETF GBP Hedged', 'BBG TIPS 1-10 UCITS ETF', 'iShares Core Global Aggregate Bond UCITS ETF', 'iShares Physical Gold GBP Hedged ETC', 'VICI Properties INC', 'Digital Realty Trust Inc', 'UK Gilt 10Y', 'World_min_vol_etf', 'iNAV iShares Edge MSCI Europe Minimum Volatility Advanced UCITS ETF EUR Acc GBP', 'snp_min_vol_etf', 'ISHARES EDGE MSCI EM MIN VOL', 'iShares North Amrican Equity Index Fund (UK)', 'SPDR World Technology', 'Amundi MSCI Robotics & AI ESG', 'HSBC MSCI China A UCITS ETF GBP iNAV ', 'Artemis Global Emerging Markets Fund', 'HSBC Global investment funds - Frontier Markets (USD) - took GBP price', 'BNP Paribas Funds - Aqua', 'GAM Sustainable Emerging Equtiy', 'ACS World ESG Insight Equity Fund', 'Black Rock Global Funds - Sustainable Energy Fund (new energy companies, emphasis on renewables and low emissions)', 'Pictet - Global environmental opportunities', 'ISHARES CORE FTSE 100 ACC', 'INVESCO FTSE RAFI UK 100', 'VANG FTSE100 GBPD', 'Fidelity Funds - European Dynamic Growth Fund', 'iShares Edge MSCI Europe Quality Factor UCITS ETF', 'Vanguard ESG Developed Europe Index Fund (EUR)']
#
# First few rows:
#         Date  iShares J.P. Morgan USD EM Bond UCITS ETF (GBP hedged)  \
# 0 2020-05-15                                             4.4275
# 1 2020-05-18                                             4.4925
# 2 2020-05-19                                             4.5198
# 3 2020-05-20                                             4.5705
# 4 2020-05-21                                             4.6015
#
#    JPMorgan GBP Ultra-Short Income UCITS ETF GBP (Acc)  \
# 0                                           100.7675
# 1                                           100.7825
# 2                                           100.7900
# 3                                           100.8150
# 4                                           100.8375
#
#    iShares Global Corp Bond UCITS ETF GBP Hedged  BBG TIPS 1-10 UCITS ETF  \
# 0                                         5.1340                    13.75
# 1                                         5.1480                    13.77
# 2                                         5.1575                    13.78
# 3                                         5.1685                    13.80
# 4                                         5.1935                    13.81
#
#    iShares Core Global Aggregate Bond UCITS ETF  \
# 0                                        4.2685
# 1                                        4.2677
# 2                                        4.2318
# 3                                        4.2550
# 4                                        4.2563
#
#    iShares Physical Gold GBP Hedged ETC  VICI Properties INC  \
# 0                                   NaN              12.6248
# 1                                   NaN              13.5632
# 2                                   NaN              14.0746
# 3                                   NaN              14.6537
# 4                                   NaN              14.9877
#
#    Digital Realty Trust Inc  UK Gilt 10Y  ...  \
# 0                  107.9049          NaN  ...
# 1                  107.9064          NaN  ...
# 2                  107.2822          NaN  ...
# 3                  108.5534          NaN  ...
# 4                  106.9092          NaN  ...
#
#    GAM Sustainable Emerging Equtiy  ACS World ESG Insight Equity Fund  \
# 0                          16.1229                                NaN
# 1                          16.3163                                NaN
# 2                          16.4333                                NaN
# 3                          16.5961                                NaN
# 4                          16.6555                                NaN
#
#    Black Rock Global Funds - Sustainable Energy Fund (new energy companies, emphasis on renewables and low emissions)  \
# 0                                               7.72
# 1                                               7.94
# 2                                               7.98
# 3                                               8.13
# 4                                                NaN
#
#    Pictet - Global environmental opportunities  ISHARES CORE FTSE 100 ACC  \
# 0                                          NaN                     9602.5
# 1                                          NaN                    10020.0
# 2                                          NaN                     9948.0
# 3                                          NaN                    10060.0
# 4                                          NaN                     9976.0
#
#    INVESCO FTSE RAFI UK 100  VANG FTSE100 GBPD  \
# 0                    779.05            25.6175
# 1                    815.95            26.7300
# 2                    810.25            26.5200
# 3                    818.20            26.7950
# 4                    805.95            26.5750
#
#    Fidelity Funds - European Dynamic Growth Fund  \
# 0                                            NaN
# 1                                          2.079
# 2                                          2.073
# 3                                          2.113
# 4                                          2.101
#
#    iShares Edge MSCI Europe Quality Factor UCITS ETF  \
# 0                                             5.6045
# 1                                             5.8090
# 2                                             5.8020
# 3                                             5.8815
# 4                                             5.8330
#
#    Vanguard ESG Developed Europe Index Fund (EUR)
# 0                                             NaN
# 1                                       158.72891
# 2                                       157.14651
# 3                                       159.64851
# 4                                       158.18222
#
# [5 rows x 31 columns]

# %%
# Save to the processed folder
output_path = os.path.join("..", "processed", "master_securities_database.xlsx")
master_df.to_excel(output_path, index=False)

print(f"✅ Master DataFrame saved to: {output_path}")
print(f"Shape: {master_df.shape[0]} rows, {master_df.shape[1]} columns")
print(f"File size: {master_df.memory_usage(deep=True).sum() / 1024:.1f} KB")
# Out:
# ✅ Master DataFrame saved to: ../processed/master_securities_database.xlsx
# Shape: 1276 rows, 31 columns
# File size: 309.2 KB
